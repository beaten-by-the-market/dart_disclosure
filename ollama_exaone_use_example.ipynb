# %% [markdown]
# <a href="https://colab.research.google.com/github/beaten-by-the-market/dart_disclosure/blob/main/ollama_exaone_use_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 구글 코랩 환경에서 NVIDA GPU, Ollama 설치 등 필요한 설정

# %%
# Install debconf-utils and preset keyboard configuration
# !sudo apt-get -y install debconf-utils
# !echo "keyboard-configuration keyboard-configuration/layoutcode string us" | sudo debconf-set-selections
# !echo "keyboard-configuration keyboard-configuration/variant select English (US)" | sudo debconf-set-selections

# Run installation commands with DEBIAN_FRONTEND=noninteractive
# !curl -fsSL https://ollama.com/install.sh | sh
# !DEBIAN_FRONTEND=noninteractive sudo apt update
# !DEBIAN_FRONTEND=noninteractive sudo apt install -y pciutils
# !DEBIAN_FRONTEND=noninteractive sudo apt-get update && sudo apt-get install -y cuda-drivers

import os
os.environ.update({'LD_LIBRARY_PATH': '/usr/lib64-nvidia'})

# 필요한 라이브러리 설치
# !pip install langchain-ollama

# ollama 실행
# !nohup ollama serve &
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   debconf-utils
# 0 upgraded, 1 newly installed, 0 to remove and 30 not upgraded.
# Need to get 57.0 kB of archives.
# After this operation, 108 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 debconf-utils all 1.5.79ubuntu1 [57.0 kB]
# Fetched 57.0 kB in 1s (71.7 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package debconf-utils.
# ...

# %% [markdown]
# ## 엑사원 다운로드 및 확인

# %%
# !ollama pull exaone3.5
# !ollama list
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest
# pulling fffbdeec0c33...   0% ▕▏    0 B/4.8 GB                  pulling manifest
# pulling fffbdeec0c33...   0% ▕▏    0 B/4.8 GB                  pulling manifest
# pulling fffbdeec0c33...   0% ▕▏    0 B/4.8 GB                  pulling manifest
# pulling fffbdeec0c33...   0% ▕▏ 6.1 MB/4.8 GB                  pulling manifest
# pulling fffbdeec0c33...   1% ▕▏  31 MB/4.8 GB                  pulling manifest
# pulling fffbdeec0c33...   2% ▕▏  89 MB/4.8 GB                  pulling manifest
# pulling fffbdeec0c33...   3% ▕▏ 141 MB/4.8 GB                  pulling manifest
# pulling fffbdeec0c33...   3% ▕▏ 158 MB/4.8 GB                  pulling manifest
# pulling fffbdeec0c33...   4% ▕▏ 188 MB/4.8 GB                  pulling manifest
# ...

# %% [markdown]
# ## 패키지 import

# %%
# 필요한 모듈 임포트
from langchain_core.prompts import ChatPromptTemplate
from langchain_ollama.llms import OllamaLLM
from IPython.display import Markdown

# %%
# 프롬프트 템플릿 정의
template = """질문: {question}

답변:"""

# 프롬프트 만들기
prompt = ChatPromptTemplate.from_template(template)

# EXAONE3.5 모델 로드
model = OllamaLLM(model="exaone3.5")

# 체인 구성
chain = prompt | model

# 질문하고 결과 표시하기
response = chain.invoke({"question": "한국의 역사에 대해 간략히 설명해주세요."})
display(Markdown(response))
# Out:
# 한국의 역사는 오랜 시간 동안 다양한 문화와 정치적 변화를 거쳐왔습니다:
#
# 1. **선사 시대 (약 70만 년 전 ~ 기원전 3세기)**: 이 시기에는 고인돌과 같은 유물들이 발견되며 초기 인류의 거주 흔적이 보입니다.
#
# 2. **삼국 시대 (기원전 1세기 ~ 668년)**: 고구려, 백제, 신라 세 나라가 서로 경쟁하며 발전했습니다. 특히 신라는 삼국 통일을 이루게 됩니다.
#
# 3. **통일 신라 시대 (668년 ~ 935년)**: 신라는 한반도를 통일하고 불교 문화를 번성시킵니다. 이 시기에는 불국사와 석굴암 같은 유네스코 세계문화유산이 건립되었습니다.
#
# 4. **고려 시대 (918년 ~ 1392년)**: 불교 문화가 더욱 발전했으며, 중국의 문화와 제도를 수용하면서 중앙집권적 체제를 구축했습니다. 고려청자 등 문화적 성취가 이루어졌습니다.
#
# 5. **조선 시대 (1392년 ~ 1910년)**: 유교 사상을 기반으로 한 사회 체계가 구축되었고, 한글 창제와 함께 과학, 예술 분야에서도 발전을 이루었습니다. 세종대왕 시기에 한글이 창제되어 민중 교육과 문화 발전에 큰 기여를 했습니다.
#
# 6. **일제 강점기 (1910년 ~ 1945년)**: 일본의 식민지 지배 아래에서 민족적 자주성과 독립 운동이 활발하게 일어났습니다.
#
# 7. **현대 한국 (1945년 ~ 현재)**: 광복 이후 분단과 한국전쟁을 겪으며 경제적으로 급속히 성장했습니다. 경제개발 5개년 계획을 통해 '한강의 기적'이라 불리는 경제성장을 이루었고, 현재는 선진국으로 자리매김하고 있습니다. 국제 사회에서의 역할도 점차 커지고 있습니다.
#
# 이러한 역사적 변화를 통해 한국은 고유의 문화를 유지하면서도 세계화의 흐름 속에서 발전해오고 있습니다.
